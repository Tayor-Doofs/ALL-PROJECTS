# %%
# %load_extautoreload

# !pip install scikit-optimize

# %autoreload2
# Out:
# UsageError: Line magic function `%load_extautoreload` not found.

# %%
from google.colab import drive
drive.mount('MyDrive/')
# Out:
# Drive already mounted at MyDrive/; to attempt to forcibly remount, call drive.mount("MyDrive/", force_remount=True).

# %%
file_path = "/content/MyDrive/My Drive/Problem Statement/movies.csv"

# %%
import pandas as pd

# %%
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# %%
df.head()
# Out:
#           id                         title  year date_published  duration  \
# 0  tt0012494                  Der müde Tod  2017       9/6/2017        97
# 1  tt0038733    A Matter of Life and Death  2017      8/12/2017       104
# 2  tt0361953  The Nest of the Cuckoo Birds  2017     16/10/2017        81
# 3  tt0235166              Against All Hope  2017     20/10/2017        90
# 4  tt0337383  Vaikai is Amerikos viesbucio  2017       9/3/2017        88
#
#         country worlwide_gross_income                 languages  \
# 0       Germany               $ 12156                    German
# 1            UK              $ 124241  English, French, Russian
# 2           USA                   NaN                   English
# 3           USA                   NaN                   English
# 4  Soviet Union                   NaN       Lithuanian, Russian
#
#                               production_company
# 0                               Decla-Bioscop AG
# ...
